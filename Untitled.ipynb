# %% [markdown]
# ### Wrapper API
#
# wrapper = ModelWrapper()
#
# seq = geney.random_sequence(L=524_000)
#
# All tokenization should be handled internally within the core functions.
#
#
# E = wrapper.embed(seq)
# P = wrapper.get_position_base_logits(seq)
# PS = wrapper.logits_for_seq(seq)

# %% [markdown]
# ###
